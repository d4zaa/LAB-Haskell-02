-- %%
convertir x = x * 1.8 + 32

procesarLecturas :: (Double -> Double) -> [Double] -> [Double]
procesarLecturas f lecturas = map f lecturas

--test
procesarLecturas convertir [0, 10, 20, 30]
-- Out:
-- Line 4: Eta reduce
-- Found:
-- procesarLecturas f lecturas = map f lecturas
-- Why not:
-- procesarLecturas = map
-- [32.0,50.0,68.0,86.0]

-- %%
crearFiltro :: (a -> Bool) -> ([a] -> [a])
crearFiltro f x = filter f x


--test
soloPares = crearFiltro even
soloPares [1..10] == [2,4,6,8,10]
-- Out:
-- Line 2: Eta reduce
-- Found:
-- crearFiltro f x = filter f x
-- Why not:
-- crearFiltro = filter
-- True

-- %%
enRango :: Int -> Int -> (Int -> Bool)
enRango min max = \x -> x >= min && x <= max

--test
entre5y10 = enRango 5 10
entre5y10 7
-- Out:
-- Line 2: Redundant lambda
-- Found:
-- enRango min max = \ x -> x >= min && x <= max
-- Why not:
-- enRango min max x = x >= min && x <= max
-- True

-- %%
potenciador :: Int -> (Int -> Int)
potenciador n = (\x -> x ^ n)

--test
potenciador5 = poteciador 5
potenciador5
-- Out:
-- Line 2: Redundant lambda
-- Found:
-- potenciador n = (\ x -> x ^ n)
-- Why not:
-- potenciador n x = x ^ nLine 2: Avoid lambda using `infix`
-- Found:
-- (\ x -> x ^ n)
-- Why not:
-- (^ n)Line 2: Redundant bracket
-- Found:
-- (\ x -> x ^ n)
-- Why not:
-- \ x -> x ^ n
-- <interactive>:1:1: error: [GHC-39999]
--     • No instance for ‘Show (Int -> Int)’ arising from a use of ‘print’
--         (maybe you haven't applied a function to enough arguments?)
--     • In a stmt of an interactive GHCi command: print it
